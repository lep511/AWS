# %%
import sagemaker, boto3, json
from sagemaker import get_execution_role


# create a sagemaker execution role via the AWS SageMaker console, then paste in the arn here
role = 'arn:aws:iam::528038902135:role/service-role/AmazonSageMaker-ExecutionRole-20220120T142266'

# %%
aws_region = boto3.Session().region_name
sess = sagemaker.Session()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_573/1637221777.py in <module>
# ----> 1 aws_region = boto3.Session().region_name
#       2 sess = sagemaker.Session()
#
# NameError: name 'boto3' is not defined
