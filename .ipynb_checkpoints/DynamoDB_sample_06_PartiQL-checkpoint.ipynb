# %%
# %%writefile ~/.aws/credentials
# [default]
# aws_access_key_id = AKIATGHPHXPHNGYAVKFK
# aws_secret_access_key = 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
# Out:
# Overwriting /home/studio-lab-user/.aws/credentials

# %%
import boto3
import pandas as pd
import numpy as np
import json
from boto3.dynamodb.conditions import Key, Attr
from botocore.exceptions import ClientError

# %%
# Get the service resource.
dynamodb = boto3.client('dynamodb')

# %%
df = pd.read_csv("music.csv")
df.drop(columns="lyrics", inplace=True)
df_c = df.sample(500)
df_c.rename(columns={"artist_name": "Artist", "track_name": "SongTitle"}, inplace=True)

# %%
for i in range(400):
    try:
        artist = str(df.artist_name.iloc[i])
        song_title = str(df.track_name.iloc[i])
        genre = str(df.genre.iloc[i])
        stmt = f"INSERT INTO PrometheonMusic value {{'Artist' : '{artist}', 'SongTitle' : '{song_title}', 'genre' : '{genre}'}}"    
        dynamodb.execute_statement(Statement= stmt)
    except:
        pass

# %%
stmt = """
SELECT * 
FROM "PrometheonMusic" 
WHERE "energy" < 0.97
"""

# %%
result = dynamodb.execute_statement(Statement= stmt, ReturnConsumedCapacity="TOTAL")

# %%
result['ConsumedCapacity']
# Out:
# {'TableName': 'PrometheonMusic', 'CapacityUnits': 14.5}

# %%
count_items = len(result['Items'])
count_items
# Out:
# 245

# %%
df = pd.DataFrame(result['Items'])

# %%
def chang_type(elem):
    if 'N' in elem:
        try:
            return int(elem['N'])
        except:
            return float(elem['N'])
    elif 'S' in elem:
        return elem['S']

# %%
df.applymap(lambda x: chang_type(x))
# Out:
#      Unnamed: 0  night/time   sadness  danceability       topic  \
# 0         64801    0.000634  0.000634      0.756309  world/life
# 1         62660    0.067065  0.000822      0.703238       music
# 2         58222    0.001815  0.001815      0.718401    violence
# 3         65387    0.001012  0.001012      0.664248  world/life
# 4           835    0.000907  0.000907      0.358822  world/life
# ..          ...         ...       ...           ...         ...
# 240       82306    0.090927  0.001196      0.886277     obscene
# 241       40293    0.001754  0.131315      0.469295    romantic
# 242       41967    0.001645  0.137612      0.273259  world/life
# 243       66274    0.120448  0.077657      0.596014  world/life
# 244       55687    0.034687  0.383203      0.498538    violence
#
#      instrumentalness  shake the audience   obscene  world/life  violence  \
# 0            0.000943            0.000634  0.000634    0.499896  0.000634
# ...

# %%
from decimal import Decimal

# %%
json_df = df_c.to_json(orient="records")
json_df = json_df.replace("\'", "´")

# %%
parsed = json.loads(json_df, parse_float=Decimal)

# %%
dynamodb = boto3.resource('dynamodb')
table = dynamodb.Table('PrometheonMusic')

# %%
with table.batch_writer() as writer:
    for item in parsed:
        writer.put_item(Item=item)

# %%
len(table.key_schema)
# Out:
# 2
