# %%
# %%writefile ~/.aws/credentials
# [default]
# aws_access_key_id = AKIAWJ36C65VS7CSOPOM
# aws_secret_access_key = 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
# Out:
# Overwriting /home/studio-lab-user/.aws/credentials

# %%
import sys
import logging
import os
import boto3
import json
from zipfile import ZipFile
from botocore.exceptions import ClientError
from pathlib import Path
from importlib import reload
from os import listdir
from os.path import isfile, join
sys.path.append("../../AWS")
import dynamodb
reload(dynamodb)
from dynamodb import DynamoTable

# %%
dt = DynamoTable()

# %%
dt.create_table(table_name="dragon_stats", 
                partition_key="dragon_name", 
                partition_key_type="S", 
                provisioned=False
)

dt.load_json("dragon_stats_one.json")
dt.load_json("dragon_stats_two.json")

# %%
dt.create_table(table_name="dragons", 
                partition_key="dragon_name", 
                partition_key_type="S", 
                provisioned=False
)

dt.create_table(table_name="dragon_current_power", 
                partition_key="game_id", 
                partition_key_type="S", 
                provisioned=False
)

dt.create_table(table_name="dragon_bonus_attack", 
                partition_key="breath_attack", 
                partition_key_type="S", 
                sort_key="range", 
                sort_key_type="N", 
                provisioned=False
)

dt.create_table(table_name="dragon_family", 
                partition_key="family", 
                partition_key_type="S", 
                provisioned=False
)

# %%
dt = DynamoTable("dragons")
dt.load_json("dragons.json")

dt = DynamoTable("dragon_family")
dt.load_json("dragon_family.json")

dt = DynamoTable("dragon_bonus_attack")
dt.load_json("dragon_bonus_attack.json")

dt = DynamoTable("dragon_current_power")
dt.load_json("dragon_current_power.json")

# %% [markdown]
# ## 1. Subir el sitio web a S3
#
# Hemos preparado un script para usted que cargará su sitio web. No necesita escribir ningún código, y no se le pedirá que modifique el sitio web, sin embargo para que este
# sin embargo, para que este script de carga funcione, tendrá que proporcionar un nombre de bucket de su cuenta. Así como una dirección IP desde donde estás desarrollando este ejercicio.

# %%
bucket_name = "my-bucket-304-32-5333"
region = "us-east-1"

# %%
s3_client = boto3.client('s3')
response = s3_client.create_bucket(Bucket=bucket_name)

# %%
response = s3_client.put_public_access_block(
        Bucket=bucket_name,
        PublicAccessBlockConfiguration={
            'BlockPublicAcls': False,
            'IgnorePublicAcls': False,
            'BlockPublicPolicy': False,
            'RestrictPublicBuckets': False
        },
    )

# %%
# Create a bucket policy
bucket_policy = {
    'Version': '2012-10-17',
    'Statement': [{
        'Sid': 'PublicReadGetObject',
        'Effect': 'Allow',
        'Principal': '*',
        'Action': ['s3:GetObject'],
        'Resource': f'arn:aws:s3:::{bucket_name}/*'
    }]
}

# Convert the policy from JSON dict to string
bucket_policy = json.dumps(bucket_policy)

# Set the new policy
response = s3_client.put_bucket_policy(Bucket=bucket_name, Policy=bucket_policy)

# %%
# Define the website configuration
website_configuration = {
    'ErrorDocument': {'Key': 'error.html'},
    'IndexDocument': {'Suffix': 'index2.html'},
}

# Set the website configuration
response = s3_client.put_bucket_website(Bucket=bucket_name,
                      WebsiteConfiguration=website_configuration)

# %%
def upload_file(file_name, bucket_name, object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """
    file_type = {"html": "text/html",
                 "png": "image/png",
                 "css": "text/css",
                 "js": "application/javascript",
                 "json": "text/json"
    }  
    extension_file = file_name.split(".")
    if len(extension_file) > 1:
        extension_str = extension_file[-1]
        if extension_str in file_type:
            content_type = file_type[extension_str]
        else:
            content_type = extension_str
    else:
        content_type = "-"
        
    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = os.path.basename(file_name)

    # Upload the file
    try:
        with open(file_name, "rb") as data:
            response = s3_client.put_object(
                Bucket= bucket_name, 
                Key=object_name, 
                Body=data, 
                ContentType=content_type,
                CacheControl= "max-age=0"
)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
mypath1 = "lab2/resources/website/"
mypath2 = "lab2/resources/website/images/"
files_1 = [mypath1 + f for f in listdir(mypath1) if isfile(join(mypath1, f))]
files_2 = [mypath2 + f for f in listdir(mypath2) if isfile(join(mypath2, f))]
tot_files = files_1 + files_2

for file in tot_files:
    upload_file(file, bucket_name)

# %%
url = f'http://{bucket_name}.s3-website-{region}.amazonaws.com/'
url
# Out:
# 'http://my-bucket-304-32-5333.s3-website-us-east-1.amazonaws.com/'

# %% [markdown]
# ## Rol de IAM para usar con Lambda

# %%
iam = boto3.client("iam")

# %%
path = '/'
role_name = 'call-dynamodb-role'
description = 'Lambda function role'

# %%
trust_policy={
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Action": [
                "sts:AssumeRole"
            ],
            "Principal": {
                "Service": [
                    "lambda.amazonaws.com"
                ]
            }
        }
    ]
}

# %%
# MaxSessionDuration: this setting can have a value from 1 hour to 12 hour
# Minimum value of 3600. Maximum value of 43200.
response = iam.create_role(
    Path=path,
    RoleName=role_name,
    AssumeRolePolicyDocument=json.dumps(trust_policy),
    Description=description,
    MaxSessionDuration=43200 

)

# %%
role_arn = response['Role']['Arn']

# %%
policy_arn = ["arn:aws:iam::aws:policy/AmazonDynamoDBFullAccess",
               "arn:aws:iam::aws:policy/AWSXrayWriteOnlyAccess",
               "arn:aws:iam::aws:policy/AmazonS3FullAccess",
               "arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole"
]

# %%
for policy in policy_arn:
    response = iam.attach_role_policy(
        PolicyArn=policy,
        RoleName=role_name
    )

# %% [markdown]
# ### lambda function - DragonSearch

# %%
# %%writefile lambda_function.py
import json
import boto3
from boto3.dynamodb.conditions import Key
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

table_name = "dragon_stats"

def lambda_handler(event, context):
    client = boto3.client('dynamodb')
    dragon_name = event.get('dragon_name_str')
    if dragon_name == None or dragon_name == "All":
        data = client.scan(
            TableName=table_name
        )
        response = data['Items']
    else:
        response = just_this_dragon(dragon_name)
    
    return response

def just_this_dragon(dragon_name):
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table(table_name)
    pk_name = table.key_schema[0]['AttributeName']
    data = table.query(
        KeyConditionExpression=Key(pk_name).eq(dragon_name)
    )
    return data['Items']
# Out:
# Overwriting lambda_function.py

# %%
file_lambda = 'lambda.zip'
with ZipFile(file_lambda, 'w') as myzip:
    myzip.write('lambda_function.py')

# %%
with open(file_lambda, 'rb') as f:
    zipped_code = f.read()

# %%
lambda_client = boto3.client('lambda')

# %%
lambda_function = "lambda_function"

# %%
response = lambda_client.create_function(
    FunctionName='lambda_function',
    Runtime='python3.8',
    Role=role_arn,
    Handler=lambda_function + '.lambda_handler',
    Code={'ZipFile': zipped_code},
    Timeout=10,
    Environment={
        'Variables': {
            'Name': 'DragonsFunction',
            'Environment': 'prod'}
    },
    Publish=True
)

# %%
lambda_arn = response['FunctionArn']

# %%
# Out:
# 'https://lku6xp0p7k.execute-api.us-east-1.amazonaws.com/prod'

# %%
# Out:
# True

# %%
# Out:
# 'http://my-bucket-304-32-2333.s3-website-us-east-1.amazonaws.com/'

# %%
gateway = boto3.client('apigateway')

# %%
api_name = "DragonSearch"

# %%
response_app = gateway.create_rest_api(
    name=api_name,
    endpointConfiguration={
        'types': [
            'REGIONAL',
        ]
    }
)

# %%
api_id = response_app["id"]
resource_path = gateway.get_resources(restApiId=api_id)['items'][0]['id']
result = gateway.get_resources(restApiId=api_id)
parent_id = next(item for item in result['items'] if item['path'] == '/')['id']
# Out:
# ---------------------------------------------------------------------------
# NotFoundException                         Traceback (most recent call last)
# /tmp/ipykernel_945/3937338936.py in <module>
#       1 api_id = response_app["ApiId"]
# ----> 2 resource_path = gateway.get_resources(restApiId=api_id)['items'][0]['id']
#       3 result = gateway.get_resources(restApiId=api_id)
#       4 parent_id = next(item for item in result['items'] if item['path'] == '/')['id']
#
# ~/.conda/envs/default/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     399                     "%s() only accepts keyword arguments." % py_operation_name)
#     400             # The "self" in this scope is referring to the BaseClient.
# --> 401             return self._make_api_call(operation_name, kwargs)
#     402
#     403         _api_call.__name__ = str(py_operation_name)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     729             error_code = parsed_response.get("Error", {}).get("Code")
#     730             error_class = self.exceptions.from_code(error_code)
# --> 731             raise error_class(parsed_response, operation_name)
#     732         else:
#     733             return parsed_response
#
# NotFoundException: An error occurred (NotFoundException) when calling the GetResources operation: Invalid API identifier specified 433519261547:rerejm1ka6

# %%
result = gateway.create_resource(
    restApiId=api_id, parentId=parent_id, pathPart=resource_path)
resource_id = result['id']

# %%
response = gateway.put_method(
    restApiId=api_id,
    resourceId=resource_id,
    authorizationType="NONE",
    httpMethod="POST",
)

# %%
response = gateway.put_method_response(
                restApiId=api_id,
                resourceId=resource_id,
                httpMethod="POST",
                statusCode='200',
                responseModels={'application/json': 'Empty'}
)

# %%
service_uri = f'arn:aws:apigateway:{region}:lambda:path/2015-03-31/functions/{lambda_arn}/invocations'
mapping_template = {}

# %%
response = gateway.put_integration(
                restApiId=api_id,
                resourceId=resource_id,
                httpMethod="POST",
                type='AWS',
                integrationHttpMethod="POST",
                uri=service_uri,
                requestTemplates={
                  "application/json":"{\"greeter\":\"$input.params('greeter')\"}"
                },
                passthroughBehavior='WHEN_NO_TEMPLATES'
)

# %%
response = gateway.put_integration_response(
    restApiId=api_id,
    resourceId=resource_id,
    httpMethod='POST',
    statusCode='200',
    responseTemplates={
        'application/json': ''
    }
)

# %%
# Create a deployment of the rest api
stage = 'prod'
response = gateway.create_deployment(
    restApiId=api_id,
    stageName=stage
)

# %%
account_id = boto3.client('sts').get_caller_identity().get('Account')
api_arn = f'arn:aws:execute-api:{region}:{account_id}:{api_id}/*/*/{resource_path}'

# %%
# Give the api deployment permission to trigger the lambda function
response = lambda_client.add_permission(
    FunctionName='lambda_function',
    StatementId='apigateway-production-aws-cms',
    Action='lambda:InvokeFunction',
    Principal='apigateway.amazonaws.com',
    SourceArn=api_arn
)
# Out:
# ---------------------------------------------------------------------------
# ResourceConflictException                 Traceback (most recent call last)
# /tmp/ipykernel_945/3919865632.py in <module>
#       1 # Give the api deployment permission to trigger the lambda function
# ----> 2 response = lambda_client.add_permission(
#       3     FunctionName='lambda_function',
#       4     StatementId='apigateway-production-aws-cms',
#       5     Action='lambda:InvokeFunction',
#
# ~/.conda/envs/default/lib/python3.9/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     399                     "%s() only accepts keyword arguments." % py_operation_name)
#     400             # The "self" in this scope is referring to the BaseClient.
# --> 401             return self._make_api_call(operation_name, kwargs)
#     402
#     403         _api_call.__name__ = str(py_operation_name)
#
# ~/.conda/envs/default/lib/python3.9/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     729             error_code = parsed_response.get("Error", {}).get("Code")
#     730             error_class = self.exceptions.from_code(error_code)
# --> 731             raise error_class(parsed_response, operation_name)
#     732         else:
#     733             return parsed_response
#
# ResourceConflictException: An error occurred (ResourceConflictException) when calling the AddPermission operation: The statement id (apigateway-production-aws-cms) provided already exists. Please provide a new statement id, or remove the existing statement.

# %%
url_api = f'https://{api_id}.execute-api.{region}.amazonaws.com/{stage}'
url_api
# Out:
# 'https://4z95qzto97.execute-api.us-east-1.amazonaws.com/prod'

# %%
file_config = 'config.js'
js_api_url = f'var API_ENDPOINT_URL_STR = "{url_api}";'

with open(file_config, 'w') as f:
    f.write(js_api_url)

upload_file(file_config, bucket_name)
url
# Out:
# 'http://my-bucket-304-32-5333.s3-website-us-east-1.amazonaws.com/'

# %%
api_client = boto3.client('apigatewayv2')

# %%
response = api_client.create_api(
    CorsConfiguration={
        'AllowCredentials': False,
        'AllowHeaders': [
            'Content-Type',
            'X-Amz-Date',
            'Authorization',
            'X-Api-Key',
            'X-Amz-Security-Token',
        ],
        'AllowMethods': [
            'OPTIONS', 'POST',
        ],
        'AllowOrigins': [
            url,
        ],
    },
    Name='dragpms',
    ProtocolType='HTTP',
)

# %%
# Out:
# {'ResponseMetadata': {'RequestId': 'dbb7b619-840b-448f-a1a7-d95ddb9e18ad',
#   'HTTPStatusCode': 201,
#   'HTTPHeaders': {'date': 'Mon, 20 Jun 2022 03:12:55 GMT',
#    'content-type': 'application/json',
#    'content-length': '579',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'dbb7b619-840b-448f-a1a7-d95ddb9e18ad',
#    'access-control-allow-origin': '*',
#    'x-amz-apigw-id': 'UADUiF7AoAMFp3A=',
#    'access-control-expose-headers': 'x-amzn-RequestId,x-amzn-ErrorType,x-amzn-ErrorMessage,Date',
#    'x-amzn-trace-id': 'Root=1-62afe5b6-4f94b0a461a283c74ca706ec'},
#   'RetryAttempts': 0},
#  'ApiEndpoint': 'https://rerejm1ka6.execute-api.us-east-1.amazonaws.com',
#  'ApiId': 'rerejm1ka6',
#  'ApiKeySelectionExpression': '$request.header.x-api-key',
#  'CorsConfiguration': {'AllowCredentials': False,
#   'AllowHeaders': ['content-type',
#    'x-amz-date',
#    'authorization',
#    'x-api-key',
#    'x-amz-security-token'],
#   'AllowMethods': ['OPTIONS', 'POST'],
#   'AllowOrigins': ['http://my-bucket-304-32-5333.s3-website-us-east-1.amazonaws.com/']},
#  'CreatedDate': datetime.datetime(2022, 6, 20, 3, 12, 54, tzinfo=tzlocal()),
#  'DisableExecuteApiEndpoint': False,
#  'Name': 'dragpms',
#  'ProtocolType': 'HTTP',
#  'RouteSelectionExpression': '$request.method $request.path'}
