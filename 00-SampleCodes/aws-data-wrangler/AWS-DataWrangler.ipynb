# %% [markdown]
# ![AWS Data Wrangler](https://repository-images.githubusercontent.com/172615836/c7960f80-32f8-11ea-824a-652e01120579 "AWS Data Wrangler")

# %%
# %%writefile ~/.aws/credentials
# [default]
# aws_access_key_id = AKIAYH4XQYWNXTS3EPJG
# aws_secret_access_key = 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
# Out:
# Overwriting /home/studio-lab-user/.aws/credentials

# %%
import secrets
import awswrangler as wr
import pandas as pd
import boto3
import pytz
from pathlib import Path
from datetime import datetime

# %%
sec = secrets.token_hex(8)
bucket = "lambda-artifacts-" + sec
region = "us-east-1"

# %%
s3_client = boto3.client('s3')
response = s3_client.create_bucket(Bucket=bucket)

# %%
path1 = f"s3://{bucket}/csv/file1.csv"
path2 = f"s3://{bucket}/csv/file2.csv"
path3 = f"s3://{bucket}/csv/file3.csv"

# %%
df = pd.read_csv("data.csv")

# %%
df1 = df.sample(500)
df2 = df.sample(500)
df3 = df.sample(100)

# %%
wr.s3.to_csv(df1, path1, index=False)
wr.s3.to_csv(df2, path2, index=False)
wr.s3.to_csv(df3, path3, index=False);

# %%
wr.s3.read_csv([path1]).head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  715023333  Existing Customer            39      M                2
# 1  771823308  Existing Customer            33      F                2
# 2  710626758  Existing Customer            44      M                4
# 3  826130133  Existing Customer            58      M                2
# 4  779135808  Existing Customer            56      F                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0      Uneducated        Married  Less than $40K          Blue
# 1      Uneducated        Unknown  Less than $40K          Blue
# 2      Uneducated        Unknown     $60K - $80K          Blue
# 3        Graduate        Married         $120K +          Blue
# 4       Doctorate         Single     $40K - $60K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              34  ...        3702.0                 1118           2584.0
# 1              21  ...        1475.0                  986            489.0
# 2              36  ...        2761.0                    0           2761.0
# 3              54  ...       31680.0                 1812          29868.0
# 4              38  ...        3609.0                 1026           2583.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.040             2585              64                0.778
# 1                 0.896             1896              33                0.833
# 2                 0.619             3706              65                0.585
# 3                 0.483             1121              25                0.562
# 4                 0.670             4318              81                0.588
#
#    Avg_Utilization_Ratio  \
# 0                  0.302
# 1                  0.668
# 2                  0.000
# 3                  0.057
# 4                  0.284
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000336
# 1                                           0.000162
# 2                                           0.000100
# 3                                           0.000327
# 4                                           0.000229
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99966
# 1                                            0.99984
# 2                                            0.99990
# 3                                            0.99967
# 4                                            0.99977
#
# [5 rows x 23 columns]

# %%
# Reading CSV by list
len(wr.s3.read_csv([path1, path2]))
# Out:
# 1000

# %%
# Reading CSV by prefix
len(wr.s3.read_csv(f"s3://{bucket}/csv/"))
# Out:
# 1100

# %%
path1 = f"s3://{bucket}/json/file1.json"
wr.s3.to_json(df3, path1)
# Out:
# ['s3://lambda-artifacts-856b2441bf7087d5/json/file1.json']

# %%
wr.s3.read_json([path1]).head()
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 624   770724558  Attrited Customer            42      M                2
# 3727  712442508  Existing Customer            52      F                4
# 9091  719740983  Existing Customer            44      F                1
# 5252  711555483  Existing Customer            43      F                3
# 8505  822170733  Attrited Customer            45      F                4
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 624          College        Married     $60K - $80K          Blue
# 3727   Post-Graduate        Married  Less than $40K          Blue
# 9091         Unknown       Divorced  Less than $40K        Silver
# 5252     High School        Unknown         Unknown          Blue
# 8505         College         Single  Less than $40K          Blue
#
#       Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 624               28  ...        7340.0                    0           7340.0
# 3727              37  ...        1438.3                  783            655.3
# 9091              34  ...       13259.0                  866          12393.0
# 5252              36  ...        8777.0                 2517           6260.0
# 8505              41  ...        3785.0                 2517           1268.0
#
#       Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 624                  0.650              838              24
# 3727                 0.733             3464              70
# 9091                 0.810             8998             102
# 5252                 0.696             4551              83
# 8505                 0.574             2401              54
#
#       Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 624                 0.412                  0.000
# 3727                0.795                  0.544
# 9091                0.672                  0.065
# 5252                0.729                  0.287
# 8505                0.742                  0.665
#
#       Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 624                                            0.989020
# 3727                                           0.000637
# 9091                                           0.000086
# 5252                                           0.000181
# 8505                                           0.994580
#
#       Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 624                                             0.01098
# 3727                                            0.99936
# 9091                                            0.99991
# 5252                                            0.99982
# 8505                                            0.00542
#
# [5 rows x 23 columns]

# %%
# Writing Parquet files
path1 = f"s3://{bucket}/parquet/file1.parquet"
path2 = f"s3://{bucket}/parquet/file2.parquet"

wr.s3.to_parquet(df1, path1)
wr.s3.to_parquet(df2, path2);

# %% [markdown]
# ### Fixed-width formatted files (only read)
# As of today, Pandas doesn't implement a `to_fwf` functionality, so let's manually write two files:

# %%
content = "1  Herfelingen 27-12-18\n"\
          "2    Lambusart 14-06-18\n"\
          "3 Spormaggiore 15-04-18"
boto3.client("s3").put_object(Body=content, Bucket=bucket, Key="fwf/file1.txt")

content = "4    Buizingen 05-09-19\n"\
          "5   San Rafael 04-09-19"
boto3.client("s3").put_object(Body=content, Bucket=bucket, Key="fwf/file2.txt")

path1 = f"s3://{bucket}/fwf/file1.txt"
path2 = f"s3://{bucket}/fwf/file2.txt"

# %%
# Reading single FWF file
wr.s3.read_fwf([path1], names=["id", "name", "date"])
# Out:
#    id          name      date
# 0   1   Herfelingen  27-12-18
# 1   2     Lambusart  14-06-18
# 2   3  Spormaggiore  15-04-18

# %% [markdown]
# ### Download object to a file path

# %%
import os

local_file_dir = "."
path1 = f"s3://{bucket}/csv/file1.csv"
local_file = os.path.join(local_file_dir, "file1.csv")
wr.s3.download(path=path1, local_file=local_file)

df_local = pd.read_csv(local_file)
df_local.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  716273133  Existing Customer            41      F                3
# 1  771411408  Attrited Customer            50      M                1
# 2  750690258  Existing Customer            49      F                2
# 3  710518308  Existing Customer            54      F                2
# 4  794528283  Existing Customer            44      M                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0        Graduate        Married  Less than $40K          Blue
# 1   Post-Graduate        Unknown    $80K - $120K          Blue
# 2        Graduate        Married  Less than $40K          Blue
# 3       Doctorate        Married  Less than $40K          Blue
# 4         College        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              36  ...        1593.0                    0           1593.0
# 1              38  ...        2673.0                    0           2673.0
# 2              39  ...        2821.0                 1995            826.0
# 3              35  ...        1685.0                    0           1685.0
# 4              28  ...        2748.0                  878           1870.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 0.610             4853              78                0.592
# 1                 1.043             4929              54                0.459
# 2                 0.620             8220             103                0.635
# 3                 0.457             4155              85                0.667
# 4                 0.633             3383              67                0.558
#
#    Avg_Utilization_Ratio  \
# 0                  0.000
# 1                  0.000
# 2                  0.707
# 3                  0.000
# 4                  0.320
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000199
# 1                                           0.998250
# 2                                           0.000303
# 3                                           0.000315
# 4                                           0.000116
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                           0.999800
# 1                                           0.001751
# 2                                           0.999700
# 3                                           0.999690
# 4                                           0.999880
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Upload object from a file path

# %%
local_file = os.path.join(local_file_dir, "file1.csv")
wr.s3.upload(local_file=local_file, path=path1)

wr.s3.read_csv(path1).head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  716273133  Existing Customer            41      F                3
# 1  771411408  Attrited Customer            50      M                1
# 2  750690258  Existing Customer            49      F                2
# 3  710518308  Existing Customer            54      F                2
# 4  794528283  Existing Customer            44      M                4
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0        Graduate        Married  Less than $40K          Blue
# 1   Post-Graduate        Unknown    $80K - $120K          Blue
# 2        Graduate        Married  Less than $40K          Blue
# 3       Doctorate        Married  Less than $40K          Blue
# 4         College        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              36  ...        1593.0                    0           1593.0
# 1              38  ...        2673.0                    0           2673.0
# 2              39  ...        2821.0                 1995            826.0
# 3              35  ...        1685.0                    0           1685.0
# 4              28  ...        2748.0                  878           1870.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 0.610             4853              78                0.592
# 1                 1.043             4929              54                0.459
# 2                 0.620             8220             103                0.635
# 3                 0.457             4155              85                0.667
# 4                 0.633             3383              67                0.558
#
#    Avg_Utilization_Ratio  \
# 0                  0.000
# 1                  0.000
# 2                  0.707
# 3                  0.000
# 4                  0.320
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000199
# 1                                           0.998250
# 2                                           0.000303
# 3                                           0.000315
# 4                                           0.000116
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                           0.999800
# 1                                           0.001751
# 2                                           0.999700
# 3                                           0.999690
# 4                                           0.999880
#
# [5 rows x 23 columns]

# %%
path1
# Out:
# 's3://lambda-artifacts-5f81355e65e98dc9/csv/file1.csv'

# %% [markdown]
# ### Upload object from a file-like object in binary mode

# %%
local_file = os.path.join(local_file_dir, "file1.csv")
with open(local_file, "rb") as local_f:
    wr.s3.upload(local_file=local_f, path=path2)

# %% [markdown]
# ### Delete objects

# %%
wr.s3.delete_objects(f"s3://{bucket}/csv")

# %% [markdown]
# -----
# ## Dynamo DB

# %%
import sys
sys.path.append("../../AWS")
from dynamodb import DynamoTable

# %%
df_s = df[["CLIENTNUM", "Marital_Status", "Income_Category", "Months_on_book"]].sample(100)

# %%
dt = DynamoTable()

# %%
dt.create_table("IncomeData", "CLIENTNUM", "N")

# %%
# Writing DataFrame
wr.dynamodb.put_df(df=df_s, table_name="IncomeData")

# %%
wr.dynamodb.read_partiql_query("SELECT * FROM IncomeData").head()
# Out:
#   Marital_Status  CLIENTNUM Months_on_book Income_Category
# 0        Married  780416433             25  Less than $40K
# 1        Married  713923233             36    $80K - $120K
# 2        Unknown  779499933             28    $80K - $120K
# 3         Single  751166508             50    $80K - $120K
# 4         Single  718632933             46  Less than $40K

# %% [markdown]
# -------
# ## AWS Glue

# %%
databases = wr.catalog.databases()
print(databases)
# Out:
#            Database Description
# 0  awswrangler_test

# %%
if "awswrangler_test" not in databases.values:
    wr.catalog.create_database("awswrangler_test")
    print(wr.catalog.databases())
else:
    print("Database awswrangler_test already exists")
# Out:
# Database awswrangler_test already exists

# %%
wr.catalog.tables(database="awswrangler_test")
# Out:
# Empty DataFrame
# Columns: [Database, Table, Description, TableType, Columns, Partitions]
# Index: []

# %%
desc = "This is my product table."

param = {
    "source": "Product Web Service",
    "class": "e-commerce"
}

comments = {
    "clientnum": "Unique client ID",
    "attrition_flag": "Internal event (customer activity) variable - if the account is closed then 1 else 0",
    "customer_age": "Demographic variable - Customer's Age in Years",
    "gender": "Demographic variable - M=Male, F=Female",
    "dependent_count": "Demographic variable - Number of dependents"
}

res = wr.s3.to_parquet(
    df=df,
    path=f"s3://{bucket}/products/",
    dataset=True,
    database="awswrangler_test",
    table="products",
    mode="overwrite",
    description=desc,
    parameters=param,
    columns_comments=comments
)

# %%
wr.catalog.tables(name_contains="prod")
# Out:
#            Database     Table                Description       TableType  \
# 0  awswrangler_test  products  This is my product table.  EXTERNAL_TABLE
#
#                                              Columns Partitions
# 0  clientnum, attrition_flag, customer_age, gende...

# %%
wr.catalog.table(database="awswrangler_test", table="products").head()
# Out:
#        Column Name    Type  Partition  \
# 0        clientnum  bigint      False
# 1   attrition_flag  string      False
# 2     customer_age  bigint      False
# 3           gender  string      False
# 4  dependent_count  bigint      False
#
#                                              Comment
# 0                                   Unique client ID
# 1  Internal event (customer activity) variable - ...
# 2     Demographic variable - Customer's Age in Years
# 3            Demographic variable - M=Male, F=Female
# 4        Demographic variable - Number of dependents

# %%
# Cleaning Up the Database
for table in wr.catalog.get_tables(database="awswrangler_test"):
    wr.catalog.delete_table_if_exists(database="awswrangler_test", table=table["Name"])

# %%
# Delete database
wr.catalog.delete_database('awswrangler_test')
