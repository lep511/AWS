# %%
import gzip
import pandas as pd
import boto3
from sagemaker import get_execution_role
import sagemaker
import logging
from botocore.exceptions import ClientError
import os

# %%
s3 = boto3.client('s3')

# %%
df = pd.read_csv("books.csv",  
                 sep=";",
                 on_bad_lines = 'skip',
                 low_memory=False,
                 encoding="latin-1"
)

# %%
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
def save_to_s3(df, bucket, object_name):
    """Pandas DataFrame.csv.Save to Amazon S3 as gz

    :param df: Pandas DataFrame
    :param bucket: Bucket to upload to
    :param object_name: S3 object name.
    """
    df.to_csv(object_name, 
           index=False, 
           compression="gzip")
    
    # Upload the file
    s3_client = boto3.client('s3')
    try:
        with open(object_name, "rb") as f:
            s3.upload_fileobj(f, bucket, object_name)
    except ClientError as e:
        logging.error(e)
    
    print(f"File saved to: s3://{bucket}/{object_name}")
    return

# %%
save_to_s3(df, "sagemaker-us-east-1-195566616656", "books_3.gz")
# Out:
# File saved to: s3://sagemaker-us-east-1-195566616656/books_3.gz

# %% [markdown]
# -------

# %%
def load_s3(bucket, object_name):
    """Read a file gz from Amazon S3 and return
    a DataFrame
    :param bucket: Bucket to load to
    :param object_name: S3 object name.
    """
    
    s3_client = boto3.client('s3')
    s3.download_file(bucket, object_name, object_name)
    dataframe = pd.read_csv(object_name, compression="gzip", index_col=0, low_memory=False)
    
    return dataframe

# %%
df = load_s3('sagemaker-us-east-1-195566616656', 'books_3.gz')

# %%
df
# Out:
#                                                    Book-Title  \
# ISBN
# 0195153448                                Classical Mythology
# 0002005018                                       Clara Callan
# 0060973129                               Decision in Normandy
# 0374157065  Flu: The Story of the Great Influenza Pandemic...
# 0393045218                             The Mummies of Urumchi
# ...                                                       ...
# 0440400988                         There's a Bat in Bunk Five
# 0525447644                            From One to One Hundred
# 006008667X  Lily Dale : The True Story of the Town that Ta...
# 0192126040                        Republic (World's Classics)
# 0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                      Book-Author Year-Of-Publication  \
# ISBN
# 0195153448    Mark P. O. Morford                2002
# 0002005018  Richard Bruce Wright                2001
# ...
