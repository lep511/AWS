# %%
# %%writefile source.txt
# [default]
# aws_access_key_id = AKIAVLOS2IVC4GSEMZ6Q
# aws_secret_access_key = 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
# Out:
# Writing source.txt

# %%
# !mv source.txt ../.aws/credentials

# %%
import os
import sys
import mimetypes
from os.path import expanduser
import boto3

# %%
s3 = boto3.client('s3')
mybucket = "bucket-3040-23-1003"

# %%
s3.create_bucket(Bucket=mybucket)
response = s3.list_buckets()
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   bucket-3040-23-1003
#   cfst-604-1eaa7bf4b1062f378c8cff5ca6e7-labs3bucket-gh0bf8vtxtq1
#   data-dom-343-12-22

# %%
# !wget https://aws-tc-largeobjects.s3.amazonaws.com/DEV-AWS-MO-BuildingRedux/downloads/app.py
# Out:
# --2022-06-05 01:13:32--  https://aws-tc-largeobjects.s3.amazonaws.com/DEV-AWS-MO-BuildingRedux/downloads/app.py
# Resolving aws-tc-largeobjects.s3.amazonaws.com (aws-tc-largeobjects.s3.amazonaws.com)... 52.92.165.97
# Connecting to aws-tc-largeobjects.s3.amazonaws.com (aws-tc-largeobjects.s3.amazonaws.com)|52.92.165.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1372 (1.3K) [text/x-python]
# Saving to: 'app.py'
#
# app.py              100%[===================>]   1.34K  --.-KB/s    in 0s
#
# 2022-06-05 01:13:32 (95.2 MB/s) - 'app.py' saved [1372/1372]

# %%
directory = expanduser('~/webapp1/')
