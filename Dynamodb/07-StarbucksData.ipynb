# %%
import pandas as pd
from spdynamodb import DynamoTable
from time import sleep
import json
from decimal import Decimal

# %%
df = pd.read_csv('directory.zip', compression='zip')

# %%
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
dt = DynamoTable()
try:
    dt.select_table('StarbucksLocations')
    print(dt)
except:
    dt.create_table(
        table_name='StarbucksLocations',
        partition_key='StoreNumber',
        partition_key_type='S',
        provisioned=False
    )

# %%
df_test = df.sample(1000)

# %%
def convert_key(row):
    return str(row['State/Province']).upper() + '#' \
            + str(row['City']).upper() + '#' \
            + str(row['Postcode']).upper()

df_test['StateCityPostcode'] = df_test.apply(lambda x: convert_key(x), axis=1)

# %%
df_test.head()
# Out:
#           Brand  Store Number                  Store Name Ownership Type  \
# 2861  Starbucks   35052-96715                         金桥店  Joint Venture
# 9712  Starbucks  50001-272225               Senai Airport       Licensed
# 1820  Starbucks  29640-253024         Tours Des Voyageurs       Licensed
# 6770  Starbucks  23607-231684  Sapporo Kanjo-dori Higashi  Joint Venture
# 6416  Starbucks  17112-179325             Rest Area KM 62       Licensed
#
#                                        Street Address            City  \
# 2861                   浦东新区, 碧云国际社区, 陈行路2388号1幢1层101室             上海市
# 9712  Lot S11, Aero Mall, Senai International Airport     Johor Bahru
# 1820                   151 Chemin du Cure Deslauriers  Mont-Tremblant
# 6770                 5-1 Honcho 2jo 1chome Higashi-ku         Sapporo
# 6416                   Jl. Tol Jakarta Cikampek KM 62        Karawang
#
#      State/Province Country  Postcode  Phone Number  \
# 2861             31      CN    201206  021-50303537
# 9712              1      MY     81250           NaN
# 1820             QC      CA   J8E 1C9           NaN
# 6770              1      JP  065-0042           NaN
# 6416             JK      ID     41373           NaN
#
#                          Timezone  Longitude  Latitude  \
# 2861       GMT+08:00 Asia/Beijing     121.58     31.24
# 9712  GMT+08:00 Asia/Kuala_Lumpur     103.67      1.64
# 1820   GMT-05:00 America/Montreal     -74.00     46.21
# 6770         GMT+09:00 Asia/Tokyo     141.38     43.08
# 6416       GMT+07:00 Asia/Jakarta     107.40     -6.39
#
#               StateCityPostcode
# 2861              31#上海市#201206
# 9712        1#JOHOR BAHRU#81250
# 1820  QC#MONT-TREMBLANT#J8E 1C9
# 6770         1#SAPPORO#065-0042
# 6416          JK#KARAWANG#41373

# %%
df_test.rename(columns={'State/Province': 'State', 'Country Code': 'CountryCode', 'Store Number': 'StoreNumber',
                        'Store Name': 'StoreName', 'Ownership Type': 'OwnershipType', 
                        'Street Address': 'StreetAddress', 'Phone Number': 'PhoneNumber'}, inplace=True)

# %%
dt.batch_pandas(df_test)

# %%
dt.create_global_secondary_index(
    att_name="Country",
    att_type="S",
    sort_index="StateCityPostcode",
    sort_type="S",
    i_name="StoreLocationIndex"
)

# %%
status = dt.check_status_gsi()
if status == 'CREATING':
    print("Global secondary index is being created, this may take a few minutes...")
    while status == 'CREATING':
        status = dt.check_status_gsi()
        sleep(30)
print("Global secondary index created.")
# Out:
# Global secondary index is being created...
# Global secondary index created.

# %%
dt.query_items('18297-164868', to_pandas=True)
# Out:
#      City                   Timezone Country Longitude Latitude Postcode  \
# 0  Laredo  GMT-06:00 America/Chicago      US    -99.48    27.61    78045
#
#        Brand State   StoreNumber  OwnershipType         StreetAddress  \
# 0  Starbucks    TX  18297-164868  Company Owned  10719 McPherson Road
#
#   StateCityPostcode  PhoneNumber                StoreName
# 0   TX#LAREDO#78045  956729-7828  Bob Bullock & McPherson

# %%
dt.query_partiql("SELECT * FROM <table> WHERE Country  = ? AND begins_with(StateCityPostcode, ?)", parameters=['US', 'NY#BROO'])
# Out:
#        City                    Timezone Country Longitude Latitude   Postcode  \
# 0  Brooklyn  GMT-05:00 America/New_York      US    -73.98    40.68  112171450
# 1  Brooklyn  GMT-05:00 America/New_York      US    -73.96    40.61  112292003
# 2  Brooklyn  GMT-05:00 America/New_York      US    -73.96    40.72      11211
# 3  Brooklyn  GMT-05:00 America/New_York      US    -74.03    40.62  112096812
# 4  Brooklyn  GMT-05:00 America/New_York      US    -73.98    40.67  112152222
#
#        Brand State   StoreNumber  OwnershipType          StreetAddress  \
# 0  Starbucks    NY    7704-13119  Company Owned  139 Flatbush Ave, N/A
# 1  Starbucks    NY  17224-171944  Company Owned     1417 Kings Highway
# 2  Starbucks    NY  22596-222524  Company Owned       154 N Seventh St
# 3  Starbucks    NY    7646-27128  Company Owned      9202 Third Avenue
# 4  Starbucks    NY     7441-1994  Company Owned         166 7th Avenue
#
#        StateCityPostcode   PhoneNumber                       StoreName
# 0  NY#BROOKLYN#112171450  718-789-3418  Flatbush Ave Atlantic Terminal
# 1  NY#BROOKLYN#112292003  718-627-1016              1417 Kings Highway
# 2      NY#BROOKLYN#11211    7183840152                154 N Seventh St
# 3  NY#BROOKLYN#112096812  718-492-5331               3rd Ave & 92nd St
# 4  NY#BROOKLYN#112152222  718-369-3098                  164 7th Avenue

# %%
dt.query_partiql("SELECT * FROM <table> WHERE Country  = ? AND contains(StateCityPostcode, ?)", parameters=['US', '#6222'])
# Out:
#          City                   Timezone Country Longitude Latitude  \
# 0  Belleville  GMT-06:00 America/Chicago      US    -90.01    38.51
#
#     Postcode      Brand State   StoreNumber OwnershipType  \
# 0  622263104  Starbucks    IL  76860-116533      Licensed
#
#                  StreetAddress        StateCityPostcode   PhoneNumber  \
# 0  5601 Belleville Crossing St  IL#BELLEVILLE#622263104  618-310-1901
#
#                   StoreName
# 0  Target Belleville T-2330

# %%
country = 'MX'
result = dt.query_partiql("SELECT * FROM <table> WHERE Country  = ?", parameters=[country])
print(f"In {country} there are {len(result)} Starbucks locations.")
# Out:
# In MX there are 22 Starbucks locations.
