# %%
import pandas as pd
from spdynamodb import DynamoTable
from time import sleep
import json
from decimal import Decimal
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.debug("test")

# %%
df = pd.read_csv('directory.zip', compression='zip')

# %%
df.head()

# %%
dt = DynamoTable()
try:
    dt.select_table('StarbucksLocations')
    print(dt)
except:
    dt.create_table(
        table_name='StarbucksLocations',
        partition_key='StoreNumber',
        partition_key_type='S',
        provisioned=False
    )
# Out:
# - Table name: StarbucksLocations
# - Table arn: arn:aws:dynamodb:us-east-1:688733876861:table/StarbucksLocations
# - Table creation: 2023-04-19 15:40:23.877000-03:00
# - [{'AttributeName': 'StoreNumber', 'KeyType': 'HASH'}]
# - [{'AttributeName': 'Country', 'AttributeType': 'S'}, {'AttributeName': 'StateCityPostcode', 'AttributeType': 'S'}, {'AttributeName': 'StoreNumber', 'AttributeType': 'S'}]
# - Point-in-time recovery status: DISABLED

# %%
# Check the status of deletion protection
dt.delete_protection
# Out:
# True

# %%
# Activate deletion protection for the table
dt.delete_protection = True

# %%
# Set the status of point in time recovery
dt.status_pitr = "ENABLED"
# Out:
# INFO:spdynamodb:Point-in-time recovery is already ENABLED.

# %%
dt
# Out:
# - Table name: StarbucksLocations
# - Table arn: arn:aws:dynamodb:us-east-1:688733876861:table/StarbucksLocations
# - Table creation: 2023-04-19 15:40:23.877000-03:00
# - [{'AttributeName': 'StoreNumber', 'KeyType': 'HASH'}]
# - [{'AttributeName': 'Country', 'AttributeType': 'S'}, {'AttributeName': 'StateCityPostcode', 'AttributeType': 'S'}, {'AttributeName': 'StoreNumber', 'AttributeType': 'S'}]
# - Point-in-time recovery status: ENABLED

# %%
df_test = df.sample(1000)

def convert_key(row):
    return str(row['State/Province']).upper() + '#' \
            + str(row['City']).upper() + '#' \
            + str(row['Postcode']).upper()

df_test['StateCityPostcode'] = df_test.apply(lambda x: convert_key(x), axis=1)

df_test['Location'] = df_test.apply(lambda x: {'lat': x['Latitude'], 'lon': x['Longitude']}, axis=1)
df_test['Address'] = df_test.apply(lambda x: {'address': x['Street Address'], 'city': x['City'], 'state': x['State/Province'], 'zip': x['Postcode']}, axis=1)
# Drop this columns
df_test.drop(['Latitude', 'Longitude', 'Street Address', 'City', 'State/Province', 'Postcode'], axis=1, inplace=True)

# %%
df_test.head()

# %%
df_test.rename(columns={'State/Province': 'State', 'Country Code': 'CountryCode', 'Store Number': 'StoreNumber',
                        'Store Name': 'StoreName', 'Ownership Type': 'OwnershipType', 
                        'Street Address': 'StreetAddress', 'Phone Number': 'PhoneNumber'}, inplace=True)

# %%
dt.batch_pandas(df_test)

# %%
dt.create_global_secondary_index(
    att_name="Country",
    att_type="S",
    sort_index="StateCityPostcode",
    sort_type="S",
    i_name="StoreLocationIndex"
)

# %%
status = dt.check_status_gsi()
if status == 'CREATING':
    print("Global secondary index is being created, this may take a few minutes...")
    while status == 'CREATING':
        status = dt.check_status_gsi()
        sleep(30)
print("Global secondary index created.")

# %%
dt.query_items('11164-99769', to_pandas=True)
# Out:
#                                              Address  \
# 0  {'zip': '926182951', 'address': '525 Spectrum ...
#
#                         Timezone Country    StateCityPostcode   PhoneNumber  \
# 0  GMT-08:00 America/Los_Angeles      US  CA#IRVINE#926182951  949-585-0051
#
#                          Location             StoreName      Brand  \
# 0  {'lat': 33.65, 'lon': -117.75}  Irvine Spectrum Mall  Starbucks
#
#    StoreNumber  OwnershipType
# 0  11164-99769  Company Owned

# %%
dt.query_partiql("SELECT * FROM <table> WHERE Country  = ? AND begins_with(StateCityPostcode, ?)", parameters=['US', 'NY#NEW'])
# Out:
#                                              Address  \
# 0  {'zip': '100256924', 'address': '2521 Broadway...
# 1  {'zip': '10017', 'address': '280 Park Avenue',...
# 2  {'zip': '100133558', 'address': '405 Broadway'...
# 3  {'zip': '10013', 'address': '32 Avenue of the ...
# 4  {'zip': '100042207', 'address': '2 Broadway', ...
# 5  {'zip': '100023133', 'address': '80 Delancey S...
# 6  {'zip': '100051003', 'address': '55 Liberty St...
# 7  {'zip': '10028', 'address': '1142 Madison Ave'...
# 8  {'zip': '10018', 'address': '525 7th Avenue', ...
#
#                      Timezone Country      StateCityPostcode     PhoneNumber  \
# 0  GMT-05:00 America/New_York      US  NY#NEW YORK#100256924  (212) 316-0374
# 1  GMT-05:00 America/New_York      US      NY#NEW YORK#10017    212 682-2586
# 2  GMT-05:00 America/New_York      US  NY#NEW YORK#100133558    646-613-0148
# 3  GMT-05:00 America/New_York      US      NY#NEW YORK#10013      2129660984
# 4  GMT-05:00 America/New_York      US  NY#NEW YORK#100042207    212-344-4290
# 5  GMT-05:00 America/New_York      US  NY#NEW YORK#100023133     917 5341397
# 6  GMT-05:00 America/New_York      US  NY#NEW YORK#100051003    212-227-0372
# 7  GMT-05:00 America/New_York      US      NY#NEW YORK#10028      2122881506
# 8  GMT-05:00 America/New_York      US      NY#NEW YORK#10018    212-869-5273
#
#                         Location                 StoreName      Brand  \
# 0  {'lat': 40.79, 'lon': -73.97}           95th & Broadway  Starbucks
# 1  {'lat': 40.76, 'lon': -73.97}               49th & Park  Starbucks
# 2     {'lat': 40.72, 'lon': -74}          Broadway & Canal  Starbucks
# 3     {'lat': 40.72, 'lon': -74}  6th Ave at Walker Street  Starbucks
# 4   {'lat': 40.7, 'lon': -74.01}                2 Broadway  Starbucks
# 5  {'lat': 40.72, 'lon': -73.99}          Allen & Delancey  Starbucks
# 6  {'lat': 40.71, 'lon': -74.01}          Liberty & Nassau  Starbucks
# 7  {'lat': 40.78, 'lon': -73.96}            85th & Madison  Starbucks
# 8  {'lat': 40.75, 'lon': -73.99}                39th & 7th  Starbucks
#
#     StoreNumber  OwnershipType
# 0    7699-45959  Company Owned
# 1  19030-193844  Company Owned
# 2  11934-106845  Company Owned
# 3  20259-184464  Company Owned
# 4    7920-88803  Company Owned
# 5   10044-99132  Company Owned
# 6    7691-52959  Company Owned
# 7  29940-255942  Company Owned
# 8    7511-12733  Company Owned

# %%
dt.query_partiql("SELECT * FROM <table> WHERE Country  = ? AND contains(StateCityPostcode, ?)", parameters=['US', '#100'], )
# Out:
#                                              Address  \
# 0  {'zip': '100256924', 'address': '2521 Broadway...
# 1  {'zip': '10017', 'address': '280 Park Avenue',...
# 2  {'zip': '100133558', 'address': '405 Broadway'...
# 3  {'zip': '10013', 'address': '32 Avenue of the ...
# 4  {'zip': '100042207', 'address': '2 Broadway', ...
# 5  {'zip': '100023133', 'address': '80 Delancey S...
# 6  {'zip': '100051003', 'address': '55 Liberty St...
# 7  {'zip': '10028', 'address': '1142 Madison Ave'...
# 8  {'zip': '10018', 'address': '525 7th Avenue', ...
#
#                      Timezone Country      StateCityPostcode     PhoneNumber  \
# 0  GMT-05:00 America/New_York      US  NY#NEW YORK#100256924  (212) 316-0374
# 1  GMT-05:00 America/New_York      US      NY#NEW YORK#10017    212 682-2586
# 2  GMT-05:00 America/New_York      US  NY#NEW YORK#100133558    646-613-0148
# 3  GMT-05:00 America/New_York      US      NY#NEW YORK#10013      2129660984
# 4  GMT-05:00 America/New_York      US  NY#NEW YORK#100042207    212-344-4290
# 5  GMT-05:00 America/New_York      US  NY#NEW YORK#100023133     917 5341397
# 6  GMT-05:00 America/New_York      US  NY#NEW YORK#100051003    212-227-0372
# 7  GMT-05:00 America/New_York      US      NY#NEW YORK#10028      2122881506
# 8  GMT-05:00 America/New_York      US      NY#NEW YORK#10018    212-869-5273
#
#                         Location                 StoreName      Brand  \
# 0  {'lat': 40.79, 'lon': -73.97}           95th & Broadway  Starbucks
# 1  {'lat': 40.76, 'lon': -73.97}               49th & Park  Starbucks
# 2     {'lat': 40.72, 'lon': -74}          Broadway & Canal  Starbucks
# 3     {'lat': 40.72, 'lon': -74}  6th Ave at Walker Street  Starbucks
# 4   {'lat': 40.7, 'lon': -74.01}                2 Broadway  Starbucks
# 5  {'lat': 40.72, 'lon': -73.99}          Allen & Delancey  Starbucks
# 6  {'lat': 40.71, 'lon': -74.01}          Liberty & Nassau  Starbucks
# 7  {'lat': 40.78, 'lon': -73.96}            85th & Madison  Starbucks
# 8  {'lat': 40.75, 'lon': -73.99}                39th & 7th  Starbucks
#
#     StoreNumber  OwnershipType
# 0    7699-45959  Company Owned
# 1  19030-193844  Company Owned
# 2  11934-106845  Company Owned
# 3  20259-184464  Company Owned
# 4    7920-88803  Company Owned
# 5   10044-99132  Company Owned
# 6    7691-52959  Company Owned
# 7  29940-255942  Company Owned
# 8    7511-12733  Company Owned

# %%
country = 'MX'
result = dt.query_partiql("SELECT * FROM <table> WHERE Country  = ?", parameters=[country])
print(f"In {country} there are {len(result)} Starbucks locations.")
# Out:
# In MX there are 21 Starbucks locations.

# %%
dt.query_partiql("SELECT * FROM <table> WHERE Country  = ? AND contains(StateCityPostcode, ?)", parameters=['US', 'MIAMI'])
# Out:
#                                              Address  \
# 0  {'zip': '331322028', 'address': '1050 Caribbea...
# 1  {'zip': '33155', 'address': '6702 Bird Road, #...
# 2  {'zip': '33137', 'address': '2937 Biscayne Blv...
#
#                      Timezone Country   StateCityPostcode   PhoneNumber  \
# 0  GMT-05:00 America/New_York      US  FL#MIAMI#331322028
# 1  GMT-05:00 America/New_York      US      FL#MIAMI#33155    3056614698
# 2  GMT-05:00 America/New_York      US      FL#MIAMI#33137  305-573-0727
#
#                         Location               StoreName      Brand  \
# 0  {'lat': 25.78, 'lon': -80.18}  RCI Sunshine Cruise #2  Starbucks
# 1   {'lat': 25.73, 'lon': -80.3}             Bird Ludlam  Starbucks
# 2  {'lat': 25.81, 'lon': -80.19}    Biscayne Blvd & 30th  Starbucks
#
#     StoreNumber  OwnershipType
# 0  23053-170652       Licensed
# 1  22267-121004  Company Owned
# 2  13824-104866  Company Owned
